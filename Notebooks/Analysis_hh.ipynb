# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("superset_hr.xlsx")
df
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        id     income_name  \
# 0                  0             0           0  81842645  1С программист
# 1                  1             1           1  82279516  1С программист
# 2                  2             2           2  83080371  1С программист
# 3                  3             3           3  83154276  1С программист
# 4                  4             4           4  87679336  1С программист
# ...              ...           ...         ...       ...             ...
# 175450        178718        178718      178689  96444696        Аналитик
# 175451        178719        178719      178690  96790151        Аналитик
# 175452        178720        178720      178691  91037911        Аналитик
# 175453        178721        178721      178692  91621631        Аналитик
# 175454        178722        178722      178693  97308518        Аналитик
#
#                                                      name  \
# 0                                          Разработчик 1С
# 1                                   Junior Разработчик 1С
# 2                                          Программист 1C
# 3                                  Младший программист 1С
# 4                                          Программист 1С
# ...                                                   ...
# 175450                   Специалист по товарной аналитике
# 175451                                  Аналитик DIRECTUM
# 175452  Аналитик программ лояльности (Клиентский анали...
# 175453                            Стратегический аналитик
# 175454                                 Аналитик Битрикс24
#
#                     published_at                created_at  \
# 0       2024-01-09T09:21:42+0300  2024-01-09T09:21:42+0300
# 1       2024-01-17T14:35:18+0300  2024-01-17T14:35:18+0300
# 2       2024-01-24T10:06:20+0300  2024-01-24T10:06:20+0300
# 3       2024-01-09T14:11:22+0300  2024-01-09T14:11:22+0300
# 4       2023-12-30T18:18:02+0300  2023-12-30T18:18:02+0300
# ...                          ...                       ...
# 175450  2024-04-08T16:32:46+0300  2024-04-08T16:32:46+0300
# 175451  2024-04-25T10:25:56+0300  2024-04-25T10:25:56+0300
# 175452  2024-04-08T10:11:35+0300  2024-04-08T10:11:35+0300
# 175453  2024-04-03T18:09:36+0300  2024-04-03T18:09:36+0300
# 175454  2024-04-18T11:20:38+0300  2024-04-18T11:20:38+0300
#
#                   collected_at  \
# 0      2024-01-24 00:00:00.000
# 1      2024-01-24 00:00:00.000
# 2      2024-01-24 00:00:00.000
# 3      2024-01-24 00:00:00.000
# 4      2024-01-24 00:00:00.000
# ...                        ...
# 175450 2024-04-25 08:45:47.060
# 175451 2024-04-25 08:45:47.060
# 175452 2024-04-25 08:45:47.060
# 175453 2024-04-25 08:45:47.060
# 175454 2024-04-25 08:45:47.060
#
#                                                     url  ...    address__city  \
# 0       https://api.hh.ru/vacancies/81842645?host=hh.ru  ...           Москва
# 1       https://api.hh.ru/vacancies/82279516?host=hh.ru  ...  Санкт-Петербург
# 2       https://api.hh.ru/vacancies/83080371?host=hh.ru  ...  Санкт-Петербург
# 3       https://api.hh.ru/vacancies/83154276?host=hh.ru  ...  Санкт-Петербург
# 4       https://api.hh.ru/vacancies/87679336?host=hh.ru  ...  Санкт-Петербург
# ...                                                 ...  ...              ...
# 175450  https://api.hh.ru/vacancies/96444696?host=hh.ru  ...              NaN
# 175451  https://api.hh.ru/vacancies/96790151?host=hh.ru  ...           Москва
# 175452  https://api.hh.ru/vacancies/91037911?host=hh.ru  ...           Москва
# 175453  https://api.hh.ru/vacancies/91621631?host=hh.ru  ...           Москва
# 175454  https://api.hh.ru/vacancies/97308518?host=hh.ru  ...              NaN
#
#           schedule__name         grade  employment__name  \
# 0            Полный день  Middle (3-6)  Полная занятость
# 1            Полный день  Junior (1-3)  Полная занятость
# 2            Полный день  Middle (3-6)  Полная занятость
# 3            Полный день  Junior (1-3)  Полная занятость
# 4            Полный день  Middle (3-6)  Полная занятость
# ...                  ...           ...               ...
# 175450       Полный день  Middle (3-6)  Полная занятость
# 175451       Полный день  Junior (1-3)  Полная занятость
# 175452       Полный день  Junior (1-3)  Полная занятость
# 175453       Полный день  Middle (3-6)  Полная занятость
# 175454  Удаленная работа  Junior (1-3)  Полная занятость
#
#                                         key_skills__names languages__names  \
# 0                              ['1С: Бухгалтерия', 'Git']               []
# 1       ['Обучение', 'Планирование карьеры', '1С прогр...               []
# 2            ['1С программирование', '1С: Предприятие 8']               []
# 3       ['ЭДО', '1С программирование', 'Обновление кон...               []
# 4                                 ['1С программирование']               []
# ...                                                   ...              ...
# 175450                                                 []               []
# 175451  ['Directum', 'BPMN', 'Directum RX', 'Аналитика...               []
# 175452      ['Маркетинговый анализ', 'ROI', 'LTV', 'CPA']               []
# 175453  ['Стратегический консалтинг', 'Экономическое м...               []
# 175454  ['Битрикс24', 'Ведение проектов', 'Составление...               []
#
#        exchange_rate salary_from_gross salary_to_gross salary_average
# 0                NaN               NaN             NaN            NaN
# 1                NaN               NaN             NaN            NaN
# 2                1.0          203000.0             NaN            NaN
# 3                1.0           40000.0         80000.0        60000.0
# 4                NaN               NaN             NaN            NaN
# ...              ...               ...             ...            ...
# 175450           NaN               NaN             NaN            NaN
# 175451           NaN               NaN             NaN            NaN
# 175452           NaN               NaN             NaN            NaN
# 175453           NaN               NaN             NaN            NaN
# 175454           1.0          113000.0             NaN            NaN
#
# [175455 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'id', 'income_name',
#        'name', 'published_at', 'created_at', 'collected_at', 'url',
#        'area__name', 'salary__currency', 'salary__gross', 'employer__name',
#        'address__city', 'schedule__name', 'grade', 'employment__name',
#        'key_skills__names', 'languages__names', 'exchange_rate',
#        'salary_from_gross', 'salary_to_gross', 'salary_average'],
#       dtype='object')

# %%
df = df[['income_name', 'grade', 'salary_from_gross', 'salary_to_gross', 'area__name']]
df
# Out:
#            income_name         grade  salary_from_gross  salary_to_gross  \
# 0       1С программист  Middle (3-6)                NaN              NaN
# 1       1С программист  Junior (1-3)                NaN              NaN
# 2       1С программист  Middle (3-6)           203000.0              NaN
# 3       1С программист  Junior (1-3)            40000.0          80000.0
# 4       1С программист  Middle (3-6)                NaN              NaN
# ...                ...           ...                ...              ...
# 175450        Аналитик  Middle (3-6)                NaN              NaN
# 175451        Аналитик  Junior (1-3)                NaN              NaN
# 175452        Аналитик  Junior (1-3)                NaN              NaN
# 175453        Аналитик  Middle (3-6)                NaN              NaN
# 175454        Аналитик  Junior (1-3)           113000.0              NaN
#
#              area__name
# 0                Москва
# 1       Санкт-Петербург
# 2       Санкт-Петербург
# 3       Санкт-Петербург
# 4       Санкт-Петербург
# ...                 ...
# 175450           Москва
# 175451           Москва
# 175452           Москва
# 175453           Москва
# 175454           Москва
#
# [175455 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# income_name               2
# grade                     0
# salary_from_gross     73448
# salary_to_gross      115608
# area__name                0
# dtype: int64

# %%
df.rename(columns = {'income_name':'Вакансия', 'grade':'Стаж', 'salary_from_gross': 'Зарплата от', 'salary_to_gross': 'Зарплата до', 'area__name': 'Город'}, inplace = True)
df
# Out:
# <ipython-input-6-c54867475b34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'income_name':'Вакансия', 'grade':'Стаж', 'salary_from_gross': 'Зарплата от', 'salary_to_gross': 'Зарплата до', 'area__name': 'Город'}, inplace = True)
#               Вакансия          Стаж  Зарплата от  Зарплата до  \
# 0       1С программист  Middle (3-6)          NaN          NaN
# 1       1С программист  Junior (1-3)          NaN          NaN
# 2       1С программист  Middle (3-6)     203000.0          NaN
# 3       1С программист  Junior (1-3)      40000.0      80000.0
# 4       1С программист  Middle (3-6)          NaN          NaN
# ...                ...           ...          ...          ...
# 175450        Аналитик  Middle (3-6)          NaN          NaN
# 175451        Аналитик  Junior (1-3)          NaN          NaN
# 175452        Аналитик  Junior (1-3)          NaN          NaN
# 175453        Аналитик  Middle (3-6)          NaN          NaN
# 175454        Аналитик  Junior (1-3)     113000.0          NaN
#
#                   Город
# 0                Москва
# 1       Санкт-Петербург
# 2       Санкт-Петербург
# 3       Санкт-Петербург
# 4       Санкт-Петербург
# ...                 ...
# 175450           Москва
# 175451           Москва
# 175452           Москва
# 175453           Москва
# 175454           Москва
#
# [175455 rows x 5 columns]

# %%
def get_valide_cols(df, renames):
    dataset = df.copy()
    dataset.rename(renames, inplace=True)
    dataset[renames.values()]
    return dataset

# %%
def get_difference_percentiles(df):
    filtered_df = df.dropna(subset=['Зарплата от', 'Зарплата до']).copy()
    filtered_df['Разница'] = filtered_df['Зарплата до'] - filtered_df['Зарплата от']
    condition = filtered_df['Разница'] > 0.8 * filtered_df['Зарплата до']
    filtered_df.loc[condition, ['Зарплата от', 'Разница']] = np.nan

    filtered_df = filtered_df.dropna(subset=['Зарплата от', 'Зарплата до'])

    filtered_df = filtered_df[filtered_df['Зарплата от'] >= 1000]
    filtered_df = filtered_df[filtered_df['Зарплата до'] >= 10000]

    filtered_df['Коэффициент разницы'] = np.where(filtered_df['Зарплата до'] != 0,
                                                      filtered_df['Разница'] / filtered_df['Зарплата до'],
                                                      np.nan)

    perc25 = filtered_df['Коэффициент разницы'].quantile(0.25)
    perc50 = filtered_df['Коэффициент разницы'].quantile(0.50)
    perc75 = filtered_df['Коэффициент разницы'].quantile(0.75)

    return perc25, perc50, perc75


def fill_na_salary(df, coef):
    result_df = df.copy()
    result_df['Зарплата до'] = result_df['Зарплата до'].fillna(result_df['Зарплата от'] / (1-coef))
    result_df['Зарплата от'] = result_df['Зарплата от'].fillna(result_df['Зарплата до'] * (1-coef))
    return result_df

# %%
def preprocessing_data(df):
    df_new = df.copy()

    missing_data = df_new[df["Зарплата от"].isnull() & df_new["Зарплата до"].isnull()]
    df_new = df_new.drop(missing_data.index)

    perc25, perc50, perc75 = get_difference_percentiles(df_new)
    df_filled_salary = fill_na_salary(df_new, perc50)

    rename_cols = {
        'income_name':'Вакансия',
        'grade':'Стаж',
        'salary_from_gross':'Зарплата от',
        'salary_to_gross': 'Зарплата до',
        'area__name': 'Город'
    }
    df_result = get_valide_cols(df_filled_salary, rename_cols)
    return df_result

# %%
df_prep = preprocessing_data(df)

# %%
df_prep
# Out:
#               Вакансия          Стаж  Зарплата от  Зарплата до  \
# 2       1С программист  Middle (3-6)     203000.0     324800.0
# 3       1С программист  Junior (1-3)      40000.0      80000.0
# 6       1С программист  Middle (3-6)     169500.0     282500.0
# 10      1С программист  Middle (3-6)     169500.0     271200.0
# 12      1С программист  Middle (3-6)     169500.0     271200.0
# ...                ...           ...          ...          ...
# 175427        Аналитик  Junior (1-3)     113000.0     135600.0
# 175442        Аналитик  Junior (1-3)      90000.0     120000.0
# 175444        Аналитик  Junior (1-3)     169500.0     282500.0
# 175449        Аналитик  Junior (1-3)      50000.0      80000.0
# 175454        Аналитик  Junior (1-3)     113000.0     180800.0
#
#                   Город
# 2       Санкт-Петербург
# 3       Санкт-Петербург
# 6       Нижний Новгород
# 10      Санкт-Петербург
# 12               Москва
# ...                 ...
# 175427           Москва
# 175442           Москва
# 175444           Москва
# 175449           Москва
# 175454           Москва
#
# [109406 rows x 5 columns]

# %%
df_prep.isna().sum()
# Out:
# Вакансия       2
# Стаж           0
# Зарплата от    0
# Зарплата до    0
# Город          0
# dtype: int64

# %%
df_prep[df_prep['Вакансия'].isna()]
# Out:
#        Вакансия          Стаж  Зарплата от  Зарплата до   Город
# 161559      NaN  Junior (1-3)      55000.0      88000.0    Тула
# 163264      NaN  Junior (1-3)     120000.0     192000.0  Москва

# %%
df_prep.dropna(subset=['Вакансия'], inplace=True)

# %%
df_prep.isna().sum()
# Out:
# Вакансия       0
# Стаж           0
# Зарплата от    0
# Зарплата до    0
# Город          0
# dtype: int64

# %%
df_analysed = df_prep.copy()
df_analysed['Наименьшая зарплата'] = df_analysed['Зарплата от']
df_analysed['Наибольшая зарплата'] = df_analysed['Зарплата до']
df_analysed.groupby(['Стаж']).agg({
    'Зарплата от': 'mean',
    'Зарплата до': 'mean',
    'Наименьшая зарплата': 'min',
    'Наибольшая зарплата': 'max'
})
# Out:
#                 Зарплата от    Зарплата до  Наименьшая зарплата  \
# Стаж
# Intern (0-1)   63910.728820  112225.529214                16.95
# Junior (1-3)   85344.192067  144220.453225              7062.50
# Middle (3-6)  148988.751104  234260.794312             30000.00
# Senior (>6)   195061.777877  299300.542778             50000.00
#
#               Наибольшая зарплата
# Стаж
# Intern (0-1)             738960.0
# Junior (1-3)             542400.0
# Middle (3-6)             835024.8
# Senior (>6)              962760.0

# %%
def analysis_missing_values_vacancy(df):
    data = df.copy()

    data['Наименьшая зарплата'] = data['Зарплата от']
    data['Наибольшая зарплата'] = data['Зарплата до']

    vacancy_missing_values = data['Стаж'].isnull().groupby(data['Вакансия']).mean()
    wages_values = data.groupby(['Вакансия', 'Стаж']).agg({'Зарплата от': 'mean',
                                                           'Зарплата до': 'mean',
                                                           'Наименьшая зарплата': 'min',
                                                           'Наибольшая зарплата': 'max'})

    return vacancy_missing_values[vacancy_missing_values > 0.15], wages_values

# %%
df_analysis, df_wages = analysis_missing_values_vacancy(df_prep)
df_analysis.sort_values()
# Out:
# Series([], Name: Стаж, dtype: float64)

# %%
df_wages
# Out:
#                                                  Зарплата от    Зарплата до  \
# Вакансия                         Стаж
# 1C консультант                   Intern (0-1)   53309.931853   84670.717683
#                                  Junior (1-3)   85371.594710  132510.053426
#                                  Middle (3-6)  149097.917213  228409.318689
#                                  Senior (>6)   139626.933333  220062.466667
# 1C оператор                      Intern (0-1)   47159.773929   65876.625489
# ...                                                      ...            ...
# Специалист технической поддержки Senior (>6)    85930.555556   95556.111111
# Технический писатель             Intern (0-1)   58446.242424   86373.490909
#                                  Junior (1-3)   91167.247448  136890.366541
#                                  Middle (3-6)  123565.279091  186984.617532
#                                  Senior (>6)   151434.630000  213025.431429
#
#                                                Наименьшая зарплата  \
# Вакансия                         Стаж
# 1C консультант                   Intern (0-1)             14125.00
#                                  Junior (1-3)             17492.40
#                                  Middle (3-6)             31781.25
#                                  Senior (>6)              67800.00
# 1C оператор                      Intern (0-1)                33.90
# ...                                                            ...
# Специалист технической поддержки Senior (>6)              60000.00
# Технический писатель             Intern (0-1)             25000.00
#                                  Junior (1-3)             11300.00
#                                  Middle (3-6)             45200.00
#                                  Senior (>6)              80000.00
#
#                                                Наибольшая зарплата
# Вакансия                         Стаж
# 1C консультант                   Intern (0-1)            240000.00
#                                  Junior (1-3)            325440.00
#                                  Middle (3-6)            452000.00
#                                  Senior (>6)             300000.00
# 1C оператор                      Intern (0-1)            135600.00
# ...                                                            ...
# Специалист технической поддержки Senior (>6)             150000.00
# Технический писатель             Intern (0-1)            198880.00
#                                  Junior (1-3)            320000.00
#                                  Middle (3-6)            361600.00
#                                  Senior (>6)             292258.68
#
# [119 rows x 4 columns]

# %%
df_outliers = df_prep[['Стаж', 'Зарплата от', 'Зарплата до']]
df_outliers
# Out:
#                 Стаж  Зарплата от  Зарплата до
# 2       Middle (3-6)     203000.0     324800.0
# 3       Junior (1-3)      40000.0      80000.0
# 6       Middle (3-6)     169500.0     282500.0
# 10      Middle (3-6)     169500.0     271200.0
# 12      Middle (3-6)     169500.0     271200.0
# ...              ...          ...          ...
# 175427  Junior (1-3)     113000.0     135600.0
# 175442  Junior (1-3)      90000.0     120000.0
# 175444  Junior (1-3)     169500.0     282500.0
# 175449  Junior (1-3)      50000.0      80000.0
# 175454  Junior (1-3)     113000.0     180800.0
#
# [109404 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import mahalanobis
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2

data = df_outliers.copy()

label_encoder = LabelEncoder()
data['category_encoded'] = label_encoder.fit_transform(data['Стаж'])

# data['Средняя зарплата'] = (data['Зарплата от'] + data['Зарплата до'])/2
numerical_data = data[['Зарплата от', 'Зарплата до']]
mean = numerical_data.mean(axis=0)
cov_matrix = np.cov(numerical_data.values.T)
inv_cov_matrix = np.linalg.inv(cov_matrix)

def mahalanobis_distance(row, mean, inv_cov_matrix):
    return mahalanobis(row, mean, inv_cov_matrix)

numerical_data['mahalanobis'] = numerical_data.apply(lambda row: mahalanobis_distance(row, mean, inv_cov_matrix), axis=1)

def hamming_distance(row, reference):
    return row != reference

reference_category = data['category_encoded'].mode()[0]

data['categorical_distance'] = data['category_encoded'].apply(lambda x: hamming_distance(x, reference_category))

weight_numerical = 0.5
weight_categorical = 0.5

data['combined_distance'] = (weight_numerical * numerical_data['mahalanobis']) + (weight_categorical * data['categorical_distance'])

combined_threshold = data['combined_distance'].quantile(0.90)
data['outlier'] = data['combined_distance'] > combined_threshold

print(data)
# Out:
#                 Стаж  Зарплата от  Зарплата до  category_encoded  \
# 2       Middle (3-6)     203000.0     324800.0                 2
# 3       Junior (1-3)      40000.0      80000.0                 1
# 6       Middle (3-6)     169500.0     282500.0                 2
# 10      Middle (3-6)     169500.0     271200.0                 2
# 12      Middle (3-6)     169500.0     271200.0                 2
# ...              ...          ...          ...               ...
# 175427  Junior (1-3)     113000.0     135600.0                 1
# 175442  Junior (1-3)      90000.0     120000.0                 1
# 175444  Junior (1-3)     169500.0     282500.0                 1
# 175449  Junior (1-3)      50000.0      80000.0                 1
# 175454  Junior (1-3)     113000.0     180800.0                 1
#
#         categorical_distance  combined_distance  outlier
# 2                       True           1.510505     True
# 3                      False           0.452651    False
# 6                       True           1.237035    False
# 10                      True           1.205017    False
# 12                      True           1.205017    False
# ...                      ...                ...      ...
# 175427                 False           0.618243    False
# 175442                 False           0.374986    False
# 175444                 False           0.737035    False
# 175449                 False           0.399860    False
# 175454                 False           0.198306    False
#
# [109404 rows x 7 columns]
# <ipython-input-31-3e4852d591b9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_data['mahalanobis'] = numerical_data.apply(lambda row: mahalanobis_distance(row, mean, inv_cov_matrix), axis=1)

# %%
data[data['outlier'] == True]['Стаж'].value_counts()
# Out:
# Стаж
# Middle (3-6)    5653
# Junior (1-3)    2265
# Intern (0-1)    2072
# Senior (>6)      923
# Name: count, dtype: int64

# %%
data[data['outlier'] == True]
# Out:
#                 Стаж  Зарплата от  Зарплата до  category_encoded  \
# 2       Middle (3-6)     203000.0     324800.0                 2
# 22      Junior (1-3)     282500.0     452000.0                 1
# 28      Middle (3-6)     226000.0     361600.0                 2
# 32      Middle (3-6)      60000.0     200000.0                 2
# 36      Middle (3-6)     192100.0     192100.0                 2
# ...              ...          ...          ...               ...
# 175183  Middle (3-6)     282500.0     452000.0                 2
# 175275  Middle (3-6)     211875.0     339000.0                 2
# 175305  Middle (3-6)     226000.0     361600.0                 2
# 175348  Middle (3-6)     339000.0     542400.0                 2
# 175405   Senior (>6)     203400.0     325440.0                 3
#
#         categorical_distance  combined_distance  outlier
# 2                       True           1.510505     True
# 22                     False           1.737153     True
# 28                      True           1.720590     True
# 32                      True           1.672483     True
# 36                      True           2.062691     True
# ...                      ...                ...      ...
# 175183                  True           2.237153     True
# 175275                  True           1.591549     True
# 175305                  True           1.720590     True
# 175348                  True           2.754025     True
# 175405                  True           1.514157     True
#
# [10913 rows x 7 columns]

# %%
df_cleaned = df_prep.drop(data.index[data['outlier']])
df_cleaned
# Out:
#               Вакансия          Стаж  Зарплата от  Зарплата до  \
# 3       1С программист  Junior (1-3)      40000.0      80000.0
# 6       1С программист  Middle (3-6)     169500.0     282500.0
# 10      1С программист  Middle (3-6)     169500.0     271200.0
# 12      1С программист  Middle (3-6)     169500.0     271200.0
# 13      1С программист  Junior (1-3)     135600.0     216960.0
# ...                ...           ...          ...          ...
# 175427        Аналитик  Junior (1-3)     113000.0     135600.0
# 175442        Аналитик  Junior (1-3)      90000.0     120000.0
# 175444        Аналитик  Junior (1-3)     169500.0     282500.0
# 175449        Аналитик  Junior (1-3)      50000.0      80000.0
# 175454        Аналитик  Junior (1-3)     113000.0     180800.0
#
#                   Город  Наименьшая зарплата  Наибольшая зарплата
# 3       Санкт-Петербург              40000.0              80000.0
# 6       Нижний Новгород             169500.0             282500.0
# 10      Санкт-Петербург             169500.0             271200.0
# 12               Москва             169500.0             271200.0
# 13      Санкт-Петербург             135600.0             216960.0
# ...                 ...                  ...                  ...
# 175427           Москва             113000.0             135600.0
# 175442           Москва              90000.0             120000.0
# 175444           Москва             169500.0             282500.0
# 175449           Москва              50000.0              80000.0
# 175454           Москва             113000.0             180800.0
#
# [98491 rows x 7 columns]

# %%
df_cleaned['Наименьшая зарплата'] = df_cleaned['Зарплата от']
df_cleaned['Наибольшая зарплата'] = df_cleaned['Зарплата до']
df_cleaned.groupby(['Стаж']).agg({
    'Зарплата от': 'mean',
    'Зарплата до': 'mean',
    'Наименьшая зарплата': 'min',
    'Наибольшая зарплата': 'max'
})
# Out:
#                 Зарплата от    Зарплата до  Наименьшая зарплата  \
# Стаж
# Intern (0-1)   62252.138041  101562.746059                16.95
# Junior (1-3)   84442.871275  138649.129231              7062.50
# Middle (3-6)  112151.314068  177265.005653             30000.00
# Senior (>6)   122172.837190  191799.278397             50000.00
#
#               Наибольшая зарплата
# Стаж
# Intern (0-1)             305100.0
# Junior (1-3)             384000.0
# Middle (3-6)             305100.0
# Senior (>6)              300000.0
